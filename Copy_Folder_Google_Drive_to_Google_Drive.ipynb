# %% [markdown]
# <a href="https://colab.research.google.com/github/kemonra/printpdf/blob/master/Copy_Folder_Google_Drive_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='Nhập đường link folder Google Drive của bạn')
source_text = widgets.Text(description="Shared drive", placeholder='Nhập đường link folder Google Drive shared')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="0")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="700")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='', description='Your drive', placeholder='Nhập đường link folder Google Drive của bạn')
# Text(value='', description='Shared drive', placeholder='Nhập đường link folder Google Drive shared')
# Text(value='0', description='Từ trang')
# Text(value='0', description='Đến trang')
# Text(value='700', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        try:
            processed_name = name.replace("'", "\\'")

            results = drive_service.files().list(q=f"'{dest_folder_id}' in parents and name contains '{processed_name}' and trashed=false",
                                                fields='files(id)').execute()

            if 'files' in results and len(results['files']) > 0:
                return results['files'][0]['id']
        except Exception as e:
            print("An error occurred: ", e)

        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)
        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# An error occurred:  <HttpError 404 when requesting https://www.googleapis.com/drive/v3/files?q=%27None%27+in+parents+and+name+contains+%27TR%E1%BB%8CN+B%E1%BB%98+IPA%2BNG%E1%BB%AE+%C3%82M%2BPH%C3%81T+%C3%82M%2BTR%E1%BB%8CNG+%C3%82M%2B%C4%90%C3%81NH+V%E1%BA%A6N%27+and+trashed%3Dfalse&fields=files%28id%29&alt=json returned "File not found: .". Details: "[{'message': 'File not found: .', 'domain': 'global', 'reason': 'notFound', 'location': 'fileId', 'locationType': 'parameter'}]">
# Total files: 6
# Total files: 5
# Copy at Folder 1. KHÓA PHÁT ÂM Starting
# [Nguồn tham khảo thêm] copied. Size 0.00 MB. Speed 0.00 MB/s
# [Phat am tieng Anh_Lesson 1.pptx] copied. Size 0.42 MB. Speed 0.23 MB/s
# [Phat am tieng Anh_Lesson 2.pptx] copied. Size 0.20 MB. Speed 0.12 MB/s
# [Phat am tieng Anh_Lesson 3.pptx] copied. Size 0.26 MB. Speed 0.14 MB/s
# [Phat am tieng Anh_Lesson 4.pptx] copied. Size 0.11 MB. Speed 0.08 MB/s
# Copy at Folder 1. KHÓA PHÁT ÂM Ending
# Total files: 3
# Copy at Folder 2. NGỮ ÂM + PHÁT ÂM + TRỌNG ÂM Starting
# Total files: 23
# Copy at Folder Ngữ âm + Phát âm + Trọng âm Starting
# Total files: 1
# Copy at Folder _ BÀI TẬP PHÁT ÂM+ TRỌNG ÂM Starting
# [BT PHÁT ÂM TRỌNG ÂM.docx] copied. Size 0.01 MB. Speed 0.00 MB/s
# Copy at Folder _ BÀI TẬP PHÁT ÂM+ TRỌNG ÂM Ending
# [_ Các quy tắc đánh trọng âm.docx] copied. Size 0.01 MB. Speed 0.00 MB/s
# Total files: 2
# Copy at Folder _ IPA tiếng Anh Starting
# [A set of IPA.pdf] copied. Size 0.02 MB. Speed 0.02 MB/s
# [THE INTERNATIONAL PHONETIC ALPHABET.pdf] copied. Size 5.50 MB. Speed 6.15 MB/s
# Copy at Folder _ IPA tiếng Anh Ending
# [_ MINDMAP TRỌNG ÂM_.pdf] copied. Size 0.30 MB. Speed 0.32 MB/s
# Total files: 6
# Copy at Folder _ Ngữ âm+ Phát âm Starting
# [ SƠ ĐỒ TÓM TẮT PHÁT ÂM.pdf] copied. Size 0.25 MB. Speed 0.21 MB/s
# [44 english sounds.pdf] copied. Size 1.13 MB. Speed 1.13 MB/s
# [Chuyên đề I Phát âm.doc.pdf] copied. Size 0.55 MB. Speed 0.65 MB/s
# Total files: 1
# Copy at Folder IPA- Bảng phiên âm Quốc tế Starting
# [A set of IPA.pdf] copied. Size 0.02 MB. Speed 0.02 MB/s
# Copy at Folder IPA- Bảng phiên âm Quốc tế Ending
# [Luyện Phát Âm Tiếng Anh.pdf] copied. Size 2.77 MB. Speed 3.08 MB/s
# Total files: 5
# Copy at Folder Ngữ âm Starting
# [Chuyên đề về Ngữ âm- Lý thuyết + Bài tập có đáp án.docx] copied. Size 0.12 MB. Speed 0.08 MB/s
# [Screenshot_20221114-101527.png] copied. Size 0.27 MB. Speed 0.22 MB/s
# [Screenshot_20221114-101531.png] copied. Size 0.21 MB. Speed 0.18 MB/s
# [Screenshot_20221114-101536.png] copied. Size 0.24 MB. Speed 0.17 MB/s
# [Screenshot_20221114-101540.png] copied. Size 0.32 MB. Speed 0.19 MB/s
# Copy at Folder Ngữ âm Ending
# Copy at Folder _ Ngữ âm+ Phát âm Ending
# [_ Ngữ âm.docx] copied. Size 0.01 MB. Speed 0.01 MB/s
# Total files: 13
# Copy at Folder _ Sơ đồ Cách phát âm Starting
# [IMG_1665223780356_1665231806341.jpg] copied. Size 0.02 MB. Speed 0.02 MB/s
# [IMG_1665223780387_1665231806895.jpg] copied. Size 0.02 MB. Speed 0.02 MB/s
# [IMG_1665223780410_1665231807217.jpg] copied. Size 0.02 MB. Speed 0.02 MB/s
# [IMG_1665223780432_1665231807492.jpg] copied. Size 0.03 MB. Speed 0.02 MB/s
# [IMG_1665223780455_1665231807814.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [IMG_1665223780478_1665231808143.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [IMG_1665223780501_1665231808307.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [IMG_1665223780524_1665231808597.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [IMG_1665223780547_1665231809094.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [IMG_1665223780569_1665231809360.jpg] copied. Size 0.03 MB. Speed 0.02 MB/s
# [IMG_1665223780592_1665231809660.jpg] copied. Size 0.03 MB. Speed 0.02 MB/s
# [IMG_1665223780614_1665231809825.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [Phát âm.pdf] copied. Size 0.25 MB. Speed 0.27 MB/s
# Copy at Folder _ Sơ đồ Cách phát âm Ending
# Total files: 2
# Copy at Folder _ Sơ đồ Phát âm Starting
# [IMG_20221025_085026.jpg] copied. Size 0.15 MB. Speed 0.13 MB/s
# [IMG_20221025_085103.jpg] copied. Size 0.15 MB. Speed 0.12 MB/s
# Copy at Folder _ Sơ đồ Phát âm Ending
# Total files: 1
# Copy at Folder _ Sơ đồ Trọng âm Starting
# [IMG_20221025_085142.jpg] copied. Size 0.10 MB. Speed 0.09 MB/s
# Copy at Folder _ Sơ đồ Trọng âm Ending
# Total files: 6
# Copy at Folder _ Trọng Âm Starting
# [100 câu Bài tập về trọng âm hay.pdf] copied. Size 0.38 MB. Speed 0.32 MB/s
# Total files: 5
# Copy at Folder Bài tập trọng âm Starting
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/11xQIhvCTVQttlXaaEDVRZ6Lwl8oNAqsh/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/1j_lA2lTrLrQCWBNjWePiptRzn3UrCtmx/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/1ejVzwXVCDmM4UaRQfnre2dEajKZ4_xvv/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/1zM8V8RUu_k2a4pCQKtGlndndfziq0oNu/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/12vfO6VkuReF8Bp8F7OmfhteJNrRQ_QjJ/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# Copy at Folder Bài tập trọng âm Ending
# [Bài tập về trọng âm.pdf] exists.
# [MR.SALARY (sưu tầm các quy tắc về trọng âm).docx] copied. Size 0.01 MB. Speed 0.00 MB/s
# Total files: 4
# Copy at Folder Trọng âm Starting
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/1rqjBgnYd5_1RBPfQY99tWEw_grLlWmTf/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/1GYiRjInkHXP4vuSwj1oZGSxl5_56iD3l/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/1PQuRYlW9lDLJ-MM5o5AMTI95NJ61uiLX/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "parentNotAFolder"
# An error occurred:  <HttpError 403 when requesting https://www.googleapis.com/drive/v3/files/17uYY7rVlEuBBRhTw_7lXGIE4aSuldTPv/copy?supportsAllDrives=true&alt=json returned "The specified parent is not a folder.". Details: "[{'message': 'The specified parent is not a folder.', 'domain': 'global', 'reason': 'parentNotAFolder'}]">
# Copy at Folder Trọng âm Ending
# Total files: 4
# Copy at Folder Trọng âm- âm tiết Starting
# [chuyen-de-1.docx] copied. Size 0.06 MB. Speed 0.05 MB/s
# [40. v.mp4] copied. Size 0.19 MB. Speed 0.24 MB/s
# [41. w.mp4] copied. Size 0.12 MB. Speed 0.14 MB/s
# [42. z.mp4] copied. Size 0.18 MB. Speed 0.19 MB/s
# [43. ʒ.mp4] copied. Size 0.18 MB. Speed 0.21 MB/s
# [44. θ.mp4] copied. Size 0.17 MB. Speed 0.20 MB/s
# [5. eə.mp4] copied. Size 0.15 MB. Speed 0.15 MB/s
# [6. ei.mp4] copied. Size 0.21 MB. Speed 0.26 MB/s
# [7. ou.mp4] copied. Size 0.20 MB. Speed 0.21 MB/s
# [8. ɪə.mp4] copied. Size 0.15 MB. Speed 0.17 MB/s
# [9. u.mp4] copied. Size 0.18 MB. Speed 0.19 MB/s
# Copy at Folder _ VIDEOS 44 KHẨU HÌNH ÂM IPA Ending
# Total files: 1
# Copy at Folder BASIC SPELLING RULES Starting
# [spelling-rules-pdf.pdf] copied. Size 0.36 MB. Speed 0.40 MB/s
# Copy at Folder BASIC SPELLING RULES Ending
# [BÀI TẬP PHÁT ÂM-TRỌNG ÂM ôn thi vào anh 10.docx] copied. Size 0.19 MB. Speed 0.16 MB/s
# [CHINH PHỤC NGỮ ÂM.pdf] copied. Size 2.47 MB. Speed 3.01 MB/s
# [CHUYÊN ĐỀ NGỮ ÂM.docx] copied. Size 0.01 MB. Speed 0.01 MB/s
# Total files: 1
# Copy at Folder CHUYÊN ĐỀ PHÁT ÂM Starting
# [Chuyên đề I Phát âm.doc.pdf] copied. Size 0.55 MB. Speed 0.63 MB/s
# Copy at Folder CHUYÊN ĐỀ PHÁT ÂM Ending
# [Nguồn tham khảo thêm] copied. Size 0.00 MB. Speed 0.00 MB/s
# Total files: 1
# Copy at Folder NGỮ ÂM TOÀN TẬP Starting
# [NGỮ ÂM TOÀN TẬP.pdf] copied. Size 10.37 MB. Speed 12.30 MB/s
# Copy at Folder NGỮ ÂM TOÀN TẬP Ending
# [PRONUNCIATION - ED-S(1).doc] copied. Size 0.04 MB. Speed 0.03 MB/s
# [PRONUNCIATION - ED-S.doc] exists.
# [SÁCH Primary Pronunciation Box.pdf] copied. Size 14.62 MB. Speed 17.29 MB/s
# Total files: 9
# Copy at Folder TÓM TẮT PHÁT ÂM+ TRỌNG ÂM Starting
# [FB_IMG_1673714315837.jpg] copied. Size 0.06 MB. Speed 0.06 MB/s
# [FB_IMG_1673714317978.jpg] copied. Size 0.06 MB. Speed 0.04 MB/s
# [FB_IMG_1673714319760.jpg] copied. Size 0.09 MB. Speed 0.08 MB/s
# [FB_IMG_1673714321442.jpg] copied. Size 0.07 MB. Speed 0.06 MB/s
# [FB_IMG_1673714323179.jpg] copied. Size 0.08 MB. Speed 0.06 MB/s
# [FB_IMG_1673714325009.jpg] copied. Size 0.06 MB. Speed 0.04 MB/s
# [FB_IMG_1673714326736.jpg] copied. Size 0.06 MB. Speed 0.05 MB/s
# [FB_IMG_1673714328566.jpg] copied. Size 0.07 MB. Speed 0.05 MB/s
# [FB_IMG_1673714330224.jpg] copied. Size 0.07 MB. Speed 0.06 MB/s
# [Screenshot_20221114-102806.png] copied. Size 0.53 MB. Speed 0.40 MB/s
# [Screenshot_20221114-102810.png] copied. Size 0.49 MB. Speed 0.33 MB/s
# [Screenshot_20221114-102814.png] copied. Size 0.53 MB. Speed 0.36 MB/s
# [Screenshot_20221114-102819.png] copied. Size 0.44 MB. Speed 0.28 MB/s
# [Screenshot_20221114-102824.png] copied. Size 0.40 MB. Speed 0.29 MB/s
# [Screenshot_20221114-102829.png] copied. Size 0.39 MB. Speed 0.32 MB/s
# [Screenshot_20221114-102834.png] copied. Size 0.33 MB. Speed 0.18 MB/s
# [Trọng âm.docx] exists.
# [WORD STRESS.pptx] copied. Size 2.07 MB. Speed 1.81 MB/s
# Copy at Folder Ngữ âm+ Trọng âm Ending
# Total files: 7
# Copy at Folder PHÁT ÂM+ TRỌNG ÂM Starting
# Total files: 25
# Copy at Folder Album Dạy cách phát âm Starting
# [FB_IMG_1687414073474.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414075524.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414077174.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414078777.jpg] copied. Size 0.04 MB. Speed 0.03 MB/s
# [FB_IMG_1687414080525.jpg] copied. Size 0.03 MB. Speed 0.04 MB/s
# [FB_IMG_1687414082159.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [FB_IMG_1687414085715.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414087496.jpg] copied. Size 0.04 MB. Speed 0.03 MB/s
# [FB_IMG_1687414089311.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414090981.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [FB_IMG_1687414092779.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [FB_IMG_1687414094564.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [FB_IMG_1687414096167.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414098298.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414099934.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414103485.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414105200.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414106937.jpg] copied. Size 0.04 MB. Speed 0.03 MB/s
# [FB_IMG_1687414108636.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414110839.jpg] copied. Size 0.02 MB. Speed 0.03 MB/s
# [FB_IMG_1687414112872.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [FB_IMG_1687414114606.jpg] copied. Size 0.03 MB. Speed 0.04 MB/s
# [FB_IMG_1687414116237.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# [FB_IMG_1687414118091.jpg] copied. Size 0.04 MB. Speed 0.04 MB/s
# [FB_IMG_1687414119841.jpg] copied. Size 0.03 MB. Speed 0.03 MB/s
# Copy at Folder Album Dạy cách phát âm Ending
# [Dạy trọng âm.doc] copied. Size 0.03 MB. Speed 0.03 MB/s
# Total files: 1
# Copy at Folder MINDMAP TRỌNG TÂM 2022 Starting
# [Mindmap Trọng tâm 2022.pdf] copied. Size 1.25 MB. Speed 1.50 MB/s
# Copy at Folder MINDMAP TRỌNG TÂM 2022 Ending
# [Nguồn tham khảo thêm] exists.
# [Phat am tieng Anh_Trọng âm câu.pptx] copied. Size 0.26 MB. Speed 0.22 MB/s
# [PRONUNCIATION - ED-S.doc] exists.
# [Quy tắc đánh trọng âm trong Tiếng Anh ( Version Tiếng Việt) .pdf] copied. Size 0.18 MB. Speed 0.22 MB/s
# Copy at Folder PHÁT ÂM+ TRỌNG ÂM Ending
# Copy at Folder 2. NGỮ ÂM + PHÁT ÂM + TRỌNG ÂM Ending
# Total files: 2
# Copy at Folder 3. ĐÁNH VẦN Starting
# Total files: 1
# Copy at Folder 60 QUY TẮC ĐÁNH VẦN Starting
# [60-Quy-tac-Danh-van.pdf] copied. Size 0.48 MB. Speed 0.50 MB/s
# Copy at Folder 60 QUY TẮC ĐÁNH VẦN Ending
